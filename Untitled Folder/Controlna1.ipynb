# %% [markdown]
# ### Data Preprocessing

# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas
#!pip install openpyxl

# %%
#!pip list

# %% [markdown]
# ### Importanting data

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
df = pd.read_excel('КР-1.xlsx', sheet_name='Вар (5)')

# %%
df
# Out:
#     Площадь загальна кв.м  Этаж                   Тип  \
# 0                    9.00     1                   МАФ
# 1                   30.00     1                   МАФ
# 2                   15.00     1                   МАФ
# 3                   20.00     1                   МАФ
# 4                   30.00     1  Вбудоване приміщення
# ..                    ...   ...                   ...
# 64                  51.77     1                   МАФ
# 65                  27.26     1                   МАФ
# 66                 148.91     1                   МАФ
# 67                  50.93     1  Вбудоване приміщення
# 68                  30.00     1                   МАФ
#
#     Количество сотрудников в штаті  Кількість відгуків в гуглі  \
# 0                                2                         NaN
# 1                                2                         8.0
# 2                                2                         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Площадь загальна кв.м             69 non-null     float64
#  1   Этаж                              69 non-null     int64
#  2   Тип                               69 non-null     object
#  3   Количество сотрудников в штаті    69 non-null     int64
#  4   Кількість відгуків в гуглі        39 non-null     float64
#  5   Количество чеков                  69 non-null     float64
#  6   Среднее количество единиц в чеке  62 non-null     float64
#  7   Автомобілів в день                64 non-null     float64
#  8   Середній дохід населення          64 non-null     float64
#  9   Внутрішньоквартальна дорога       69 non-null     int64
#  10  Прогулянкова зона                 69 non-null     int64
# ...

# %%
# Drop useless
df = df.drop(['Этаж','Количество чеков'], axis='columns', inplace=False)
df.head(5)
# Out:
#    Площадь загальна кв.м                   Тип  \
# 0                    9.0                   МАФ
# 1                   30.0                   МАФ
# 2                   15.0                   МАФ
# 3                   20.0                   МАФ
# 4                   30.0  Вбудоване приміщення
#
#    Количество сотрудников в штаті  Кількість відгуків в гуглі  \
# 0                               2                         NaN
# 1                               2                         8.0
# 2                               2                         NaN
# 3                               2                         NaN
# 4                               2                         NaN
#
#    Среднее количество единиц в чеке  Автомобілів в день  \
# 0                              1.56             12679.0
# 1                              2.03             12800.0
# 2                              1.81             77106.0
# 3                              2.18                 0.0
# ...

# %% [markdown]
# ### Visualization

# %%
# Feature distribution
df['Площадь загальна кв.м'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Количество сотрудников в штаті'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Среднее количество единиц в чеке'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Автомобілів в день'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Середній дохід населення'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Внутрішньоквартальна дорога'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Прогулянкова зона'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Якість покриття перед магазином'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Стихійна торгівля'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['Зона пікніка'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Statistics

# %%
# Dataset Statistics
df.describe()
# Out:
#        Площадь загальна кв.м  Количество сотрудников в штаті  \
# count              69.000000                       69.000000
# mean               47.412725                        3.652174
# std                37.862989                        1.607209
# min                 4.000000                        2.000000
# 25%                26.720000                        2.000000
# 50%                32.300000                        4.000000
# 75%                56.240000                        4.000000
# max               232.300000                        8.000000
#
#        Кількість відгуків в гуглі  Среднее количество единиц в чеке  \
# count                   39.000000                         62.000000
# mean                    42.820513                          1.896290
# std                     81.975565                          0.218364
# min                      1.000000                          1.270000
# 25%                      5.000000                          1.770000
# ...

# %% [markdown]
# ### Mistakes

# %%
# Mistakes Deleting 
df = df.drop(df[df['Площадь загальна кв.м'] < 4].index)
df = df.drop(df[df['Середній дохід населення'] < 10000].index)
df = df.drop(df[df['Количество сотрудников в штаті'] < 1].index)
df = df.drop(df[df['Автомобілів в день'] > 12000].index)
df.describe()
# Out:
#        Площадь загальна кв.м  Количество сотрудников в штаті  \
# count              39.000000                       39.000000
# mean               44.160769                        3.487179
# std                26.093888                        1.411826
# min                 4.000000                        2.000000
# 25%                27.270000                        2.000000
# 50%                36.490000                        4.000000
# 75%                57.175000                        4.000000
# max               148.910000                        6.000000
#
#        Кількість відгуків в гуглі  Среднее количество единиц в чеке  \
# count                   20.000000                         34.000000
# mean                    47.050000                          1.890000
# std                     80.923274                          0.221988
# min                      1.000000                          1.270000
# 25%                      8.000000                          1.792500
# ...

# %% [markdown]
# ### Missing data

# %%
# Cheking Missing data
df.isnull().sum()
# Out:
# Площадь загальна кв.м                0
# Тип                                  0
# Количество сотрудников в штаті       0
# Кількість відгуків в гуглі          19
# Среднее количество единиц в чеке     5
# Автомобілів в день                   5
# Середній дохід населення             5
# Внутрішньоквартальна дорога          0
# Прогулянкова зона                    0
# Якість покриття перед магазином      0
# Стихійна торгівля                    0
# Зона пікніка                         0
# dtype: int64

# %%
df.dtypes
# Out:
# Площадь загальна кв.м               float64
# Тип                                  object
# Количество сотрудников в штаті        int64
# Кількість відгуків в гуглі          float64
# Среднее количество единиц в чеке    float64
# Автомобілів в день                  float64
# Середній дохід населення            float64
# Внутрішньоквартальна дорога           int64
# Прогулянкова зона                     int64
# Якість покриття перед магазином       int64
# Стихійна торгівля                     int64
# Зона пікніка                          int64
# dtype: object

# %%
#!pip install sklearn

# %%
from sklearn.impute import SimpleImputer
#numeric
'''SimpleImputer - класс
imputer_mean - экземпляр
fit - метод класса'''

imputer_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
df[['Кількість відгуків в гуглі']] = imputer_mean.fit_transform(df[['Кількість відгуків в гуглі']]).round()
df[['Среднее количество единиц в чеке']] = imputer_mean.fit_transform(df[['Среднее количество единиц в чеке']]).round()
df[['Автомобілів в день']] = imputer_mean.fit_transform(df[['Автомобілів в день']]).round()
df[['Середній дохід населення']] = imputer_mean.fit_transform(df[['Середній дохід населення']]).round()

# %%
df.isnull().sum()
# Out:
# Площадь загальна кв.м               0
# Тип                                 0
# Количество сотрудников в штаті      0
# Кількість відгуків в гуглі          0
# Среднее количество единиц в чеке    0
# Автомобілів в день                  0
# Середній дохід населення            0
# Внутрішньоквартальна дорога         0
# Прогулянкова зона                   0
# Якість покриття перед магазином     0
# Стихійна торгівля                   0
# Зона пікніка                        0
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
df.describe()
# Out:
#        Площадь загальна кв.м  Количество сотрудников в штаті  \
# count              39.000000                       39.000000
# mean               44.160769                        3.487179
# std                26.093888                        1.411826
# min                 4.000000                        2.000000
# 25%                27.270000                        2.000000
# 50%                36.490000                        4.000000
# 75%                57.175000                        4.000000
# max               148.910000                        6.000000
#
#        Кількість відгуків в гуглі  Среднее количество единиц в чеке  \
# count                   39.000000                         39.000000
# mean                    47.025641                          1.948718
# std                     57.221402                          0.223456
# min                      1.000000                          1.000000
# 25%                     19.000000                          2.000000
# ...

# %%
# Function Outliers
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
# Outliers
df = outliers(df)
df.describe()
# Out:
#        Площадь загальна кв.м  Количество сотрудников в штаті  \
# count              39.000000                       39.000000
# mean               43.482114                        3.487179
# std                23.514560                        1.411826
# min                 4.000000                        2.000000
# 25%                27.270000                        2.000000
# 50%                36.490000                        4.000000
# 75%                57.175000                        4.000000
# max               122.442433                        6.000000
#
#        Кількість відгуків в гуглі  Среднее количество единиц в чеке  \
# count                   39.000000                         39.000000
# mean                    44.299740                          1.962992
# std                     44.818945                          0.161257
# min                      1.000000                          1.278350
# 25%                     19.000000                          2.000000
# ...

# %% [markdown]
# ### Encoding

# %%
from sklearn import preprocessing
dfm = df
dfm['Тип'] = preprocessing.LabelEncoder().fit_transform(dfm['Тип'])
dfm
# Out:
#     Площадь загальна кв.м  Тип  Количество сотрудников в штаті  \
# 3               20.000000    1                               2
# 4               30.000000    0                               2
# 5               57.700000    0                               2
# 6               50.000000    1                               4
# 7               45.000000    1                               6
# 8               27.000000    1                               2
# 12              56.650000    1                               4
# 16              25.000000    1                               2
# 17              51.000000    1                               4
# 18              70.000000    0                               4
# 19              24.000000    1                               2
# 20              44.000000    1                               4
# 21               4.000000    0                               2
# 30              65.000000    1                               4
# ...

# %%
# Encoding categorical data
df = encoding_char(df)
df
# Out:
#     Площадь загальна кв.м  Тип  Количество сотрудников в штаті  \
# 3               20.000000    1                               2
# 4               30.000000    0                               2
# 5               57.700000    0                               2
# 6               50.000000    1                               4
# 7               45.000000    1                               6
# 8               27.000000    1                               2
# 12              56.650000    1                               4
# 16              25.000000    1                               2
# 17              51.000000    1                               4
# 18              70.000000    0                               4
# 19              24.000000    1                               2
# 20              44.000000    1                               4
# 21               4.000000    0                               2
# 30              65.000000    1                               4
# ...

# %% [markdown]
# ### Correlations

# %%
# Cheking correlations
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %%
# Removing Correlated Data
dfr = df.drop(['Тип'], axis='columns', inplace=False)
dfr.shape
# Out:
# (39, 11)

# %% [markdown]
# ### Splitting

# %%
# Splitting the dataset into the Training set and Test set
X = df.iloc[:, :-1]
y = df['Количество сотрудников в штаті']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ### Simple Linear Regression

# %%
# Fitting Simple Linear Regression to the Training set (M2)
f1 = ['Кількість відгуків в гуглі']

from sklearn.linear_model import LinearRegression
sr = LinearRegression().fit(X_train[f1], y_train)

# Getting parameters
sr.coef_, sr.intercept_
# Out:
# (array([0.01186389]), 3.190957559553937)

# %%
# Predicting the Test set results
y_pred = sr.predict(X_test[f1])

# Coefficient of determination R^2
sr.score(X_train[f1], y_train).round(3)
# Out:
# 0.174

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, sr.predict(X_train[f1]), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (1.26, 1.43)

# %%
# Visualising the Test set results
plt.scatter(X_test['Кількість відгуків в гуглі'], y_test, color = 'red')
plt.plot(X_test['Кількість відгуків в гуглі'], sr.predict(X_test[f1]), 'bo')
plt.title('Количество сотрудников в штаті vs Кількість відгуків в гуглі (Test set)')
plt.xlabel('Кількість відгуків в гуглі')
plt.ylabel('Количество сотрудников в штаті')
plt.show()

# %% [markdown]
# ### Multiple Linear Regression

# %%
#!pip install statsmodels

# %%
# Fitting Multiple Regression
mr = LinearRegression().fit(X_train, y_train)

# Coefficient of determination R^2
mr.score(X_train, y_train).round(3)
# Out:
# 1.0

# %%
# Visualising the Test set results
plt.scatter(X_test['Кількість відгуків в гуглі'], y_test, color = 'red')
plt.plot(X_test['Кількість відгуків в гуглі'], mr.predict(X_test), 'bo')
plt.title('Количество сотрудников в штаті vs Кількість відгуків в гуглі (Test set)')
plt.xlabel('Кількість відгуків в гуглі')
plt.ylabel('Количество сотрудников в штаті')
plt.show()

# %%
# Checking p-values
import statsmodels.api as sm
X1 = sm.add_constant(X_train)
mr1 = sm.OLS(y_train, X1).fit()
#mr1.pvalues
mr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ...
# Dep. Variable:     Количество сотрудников в штаті   R-squared:                       1.000
# Model:                                        OLS   Adj. R-squared:                  1.000
# Method:                             Least Squares   F-statistic:                 1.030e+25
# Date:                            Fri, 22 Oct 2021   Prob (F-statistic):          7.63e-245
# Time:                                    00:20:19   Log-Likelihood:                 827.76
# No. Observations:                              31   AIC:                            -1634.
# Df Residuals:                                  20   BIC:                            -1618.
# Df Model:                                      10
# Covariance Type:                        nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Recursive feature elimination

# %%
# Feature ranking with recursive feature elimination
from sklearn.feature_selection import RFE
n_features = X.shape[1]
estimator = LinearRegression()
selector = RFE(estimator, n_features_to_select = 3)
selector = selector.fit(X, y)

# Selected Features
selected_columns=[]
for i in range(n_features):
    if selector.support_[i] == True:
        selected_columns.append(i)
        
f_lm = []
for column in selected_columns:
    f_lm.append(X.columns[column])

# %%
# Fitting Optimized Multiple Regression
mr_rfe = LinearRegression().fit(X_train[f_lm], y_train)

# Getting parameters
mr_rfe.coef_, mr_rfe.intercept_
# Out:
# (array([9.06344920e-16, 1.00000000e+00, 1.50063522e-16]),
#  -1.687538997430238e-14)

# %%
# Predicting the Test set results
y_pred = mr_rfe.predict(X_test[f_lm])

# Coefficient of determination R^2
mr_rfe.score(X_train[f_lm], y_train).round(3)
# Out:
# 1.0

# %%
# Mean squared error
mean_squared_error(y_train, mr_rfe.predict(X_train[f_lm]), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (0.0, 0.0)

# %%
# Visualising the Test set results
plt.scatter(X_test['Кількість відгуків в гуглі'], y_test, color = 'red')
plt.plot(X_test['Кількість відгуків в гуглі'], mr_rfe.predict(X_test[f_lm]), 'bo')
plt.title('Количество сотрудников в штаті vs Кількість відгуків в гуглі (Test set)')
plt.xlabel('Кількість відгуків в гуглі')
plt.ylabel('Количество сотрудников в штаті')
plt.show()

# %% [markdown]
# ### Backward Elimination

# %%
# Backward Elimination with p-values
def backwardElimination(x, y, sl):
    x = sm.add_constant(x)
    numVars = x.shape[1]
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j] == maxVar):
                    x = x.drop(x.columns[j], axis=1)
    regressor_OLS.summary()
    return x

SL = 0.0001
X_Modeled = backwardElimination(X_train, y_train, SL)

# %%
# Fitting Optimized Multiple Regression
mr_be = LinearRegression().fit(X_Modeled, y_train)

# Coefficient of determination R^2
mr_be.score(X_Modeled, y_train).round(3)
# Out:
# 1.0

# %% [markdown]
# ### Polynomial Regression

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
X_train_p = PolynomialFeatures().fit_transform(X_train)
X_test_p = PolynomialFeatures().fit_transform(X_test)

pr = LinearRegression().fit(X_train_p, y_train)

# Getting parameters
pr.coef_, pr.intercept_
# Out:
# (array([ 1.59964099e-12,  1.13793794e-03, -2.20028268e-05,  6.48032313e-05,
#         -8.07070475e-04,  2.67807423e-15,  3.20688095e-05, -7.24829831e-05,
#          4.77364981e-05,  3.94228970e-05,  2.83052003e-06,  4.59949104e-06,
#          6.30582210e-05,  2.42774151e-03, -1.79901097e-03,  1.60655874e-04,
#          2.27587587e-03, -3.60791644e-07, -1.35472949e-06,  4.06647911e-03,
#          3.05040445e-03,  1.60288236e-03, -4.06238687e-04, -2.20028261e-05,
#          2.02735834e-05, -9.01962035e-04, -4.40056521e-05, -3.40813494e-05,
#         -3.12296044e-06,  4.97148975e-05,  7.95833054e-05, -3.53514889e-05,
#          4.59949104e-06, -3.41576808e-04,  3.60804889e-03,  1.29606463e-04,
#         -4.39030639e-06,  8.71820987e-05, -1.89043555e-04, -1.55256720e-04,
#         -1.32313270e-05,  1.80479534e-04, -5.68223330e-05, -1.61414095e-03,
#          1.41936635e-07, -7.14732995e-07, -9.61895505e-05, -1.69041341e-03,
# ...

# %%
# Predicting the Test set results
y_pred = pr.predict(X_test_p)

# Coefficient of determination R^2
pr.score(X_train_p, y_train).round(3)
# Out:
# 1.0

# %%
# Mean squared error
mean_squared_error(y_train, pr.predict(X_train_p), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (0.0, 0.85)

# %%
# Visualising the Test set results
plt.scatter(X_test['Кількість відгуків в гуглі'], y_test, color = 'red')
plt.plot(X_test['Кількість відгуків в гуглі'], pr.predict(X_test_p), 'bo')
plt.title('Количество сотрудников в штаті vs Кількість відгуків в гуглі (Test set)')
plt.xlabel('Кількість відгуків в гуглі')
plt.ylabel('Количество сотрудников в штаті')
plt.show()

# %%
# Вывод: Чем больше сотрудников работает с клитентами, тем больше отзывов в гугле.
